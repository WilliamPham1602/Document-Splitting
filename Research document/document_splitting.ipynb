# %%
from pdf2image import convert_from_path

# %%
images = convert_from_path('corpus1/TrainTestSet/Trainset/data/868212__concatenated.pdf')

# %%
image_count = 0
for image in images:
    filename = "images/p_"+str(image_count) + ".jpg"
    image.save(filename, 'JPEG')
    image_count += 1

# %%
from PIL import Image
import pytesseract

# Variable to get count of total number of pages
filelimit = image_count-1
  
# Creating a text file to write the output
outfile = "out_text.txt"
  
# Open the file in append mode so that 
# All contents of all images are added to the same file
f = open(outfile, "a")
  
# Iterate from 1 to total number of pages
for i in range(1, filelimit + 1):
  
    # Set filename to recognize text from
    # Again, these files will be:
    # page_1.jpg
    # page_2.jpg
    # ....
    # page_n.jpg
    filename = "images/p_"+str(i)+".jpg"
          
    # Recognize the text as string in image using pytesserct
    text = str(((pytesseract.image_to_string(Image.open(filename)))))
  
    # The recognized text is stored in variable text
    # Any string processing may be applied on text
    # Here, basic formatting has been done:
    # In many PDFs, at line ending, if a word can't
    # be written fully, a 'hyphen' is added.
    # The rest of the word is written in the next line
    # Eg: This is a sample text this word here GeeksF-
    # orGeeks is half on first line, remaining on next.
    # To remove this, we replace every '-\n' to ''.
    text = text.replace('-\n', '')    
  
    # Finally, write the processed text to the file.
    f.write(text)
  
# Close the file after writing all the text.
f.close()

# %%
# !conda uninstall pytesseract -y
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/tuvovan/miniforge3/envs/joon
#
#   removed specs:
#     - pytesseract
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appnope-0.1.3              |     pyhd8ed1ab_0           8 KB  conda-forge
#     argon2-cffi-bindings-21.2.0|   py38h33210d7_2          32 KB  conda-forge
#     beautifulsoup4-4.11.1      |     pyha770c72_0          96 KB  conda-forge
#     bleach-5.0.0               |     pyhd8ed1ab_0         123 KB  conda-forge
#     brotli-1.0.9               |       h1c322ee_7          18 KB  conda-forge
#     brotli-bin-1.0.9           |       h1c322ee_7          17 KB  conda-forge
# ...

# %%
# !brew install tesseract
# !conda install pytesseract -y
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/tuvovan/miniforge3/envs/joon
#
#   added / updated specs:
#     - pytesseract
#
#
# The following NEW packages will be INSTALLED:
#
#   pytesseract        conda-forge/noarch::pytesseract-0.3.10-pyhd8ed1ab_0
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
